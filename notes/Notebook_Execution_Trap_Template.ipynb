# %%
# Date: 2026-01-16
# Topic: Notebook Execution Trap Template
# Goal: Understand how to use the notebook execution trap template effectively
# What might confuse me today?

"""
NOTEBOOK TRUTH:
1) The kernel remembers state.
2) Cells can run out of order.
3) Editing a cell changes NOTHING until you rerun it.
4) Restarting the kernel deletes everything in memory.
"""
# Example to illustrate notebook execution traps
# Cell 1
a = 10      
b = 20
# Cell 2
c = a + b   
print(c)  # Outputs 30
# Cell 3    
a = 15  
# Cell 4        
d = a + b  
print(d)  # Outputs 35 if Cell 3 is run before Cell 4   
# Cell 5
# Restarting the kernel here would delete a, b, c, and d from memory    
# Cell 6
print(a)  # Would raise an error if the kernel was restarted before this cell is run    
# Cell 7
b = 25  
e = a + b  
print(e)  # Outputs 40 if Cell 3 is run before Cell 7   
# Summary:
# Always be aware of the order in which you run cells and the current state of variables in memory.
# To avoid confusion, consider restarting the kernel and running all cells in order when unsure.
# This template helps illustrate common pitfalls in notebook execution.
# Remember to always test your notebook from a fresh kernel state to ensure reproducibility.
# This template is designed to help you understand and avoid common pitfalls when working with Jupyter Notebooks.
# by ChatGPT    
# End of Notebook Execution Trap Template

# %%
a = 10      
b = 20

# %%
c = a + b   
print(c)  # Outputs 30
# Out:
# 30

# %%
a = 15

# %%
d = a + b  
print(d)  # Outputs 35 if Cell 3 is run before Cell 4
# Out:
# 35

# %%
print(a)  # Would raise an error if the kernel was restarted before this cell is run
# Out:
# 15

# %%
b = 25  
e = a + b   
print(e)  # Outputs 40 if Cell 3 is run before Cell 7
# Out:
# 40
